# %% [markdown]
# # 04. Culture Concordance
#
# This notebook compares culture calls against Bracken relative abundance for clinically important organism groups.
# Descriptive inference is centered on Mann-Whitney U tests, with AUROC reported as a companion discrimination summary.

# %%
from pathlib import Path
import sys

import pandas as pd
from IPython.display import Markdown, SVG, display

ROOT = Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import workflow_core as wc

context, base_data, base, advanced = wc.bootstrap_notebook()

# %% [markdown]
# ## Build Culture-Concordance Summaries

# %%
analysis_context = wc.base_analysis_context(context)
qc = base_data["qc"]
species_bac = base_data["species_bac"]

culture_summary, _ = base.make_culture_abundance_table(qc, species_bac)

wc.save_table(culture_summary, wc.table_path(context, 6, "culture_concordance"))
# Out:
# PosixPath('/home/ubuntu/dev/20250320_eb_summary/metagenomics_20260206/analysis_concise/tables/table_04_01_culture_concordance.tsv')

# %% [markdown]
# ## Review Numbered Outputs

# %%
culture_summary = pd.read_csv(
    wc.table_path(context, 6, "culture_concordance"), sep="\t"
)

display(culture_summary)

top_hit = culture_summary.sort_values("qvalue").iloc[0]
weakest = culture_summary.sort_values("qvalue", ascending=False).iloc[0]
summary_lines = [
    f"- Positive result: strongest descriptive agreement was {top_hit['label']} (Mann-Whitney U={top_hit['u_statistic']:.1f}, q={top_hit['qvalue']:.3g}, AUROC={top_hit['auroc']:.2f}).",
    f"- Negative result: weakest supported target here was {weakest['label']} (Mann-Whitney q={weakest['qvalue']:.3g}, AUROC={weakest['auroc']:.2f}).",
    "- Culture agreement is organism-group level, not strain-level or resistance-level agreement.",
]
display(Markdown("## Working Interpretation\n" + "\n".join(summary_lines)))
# Out:
#                      group            label  n_culture_positive  \
# 0                 s_aureus        S. aureus                  53
# 1             p_aeruginosa    P. aeruginosa                  17
# 2           klebsiella_spp  Klebsiella spp.                   5
# 3      serratia_marcescens         Serratia                   4
# 4                      gas              GAS                   4
# 5  acinetobacter_baumannii     A. baumannii                   3
# 6               e_faecalis      E. faecalis                   2
# 7        proteus_mirabilis          Proteus                   2
# 8                   e_coli          E. coli                   2
#
#    n_culture_negative  median_rel_ab_positive  median_rel_ab_negative  \
# 0                  21                0.231354                0.016885
# 1                  57                0.691509                0.055136
# 2                  69                0.283484                0.001467
# 3                  70                0.736935                0.006481
# 4                  70                0.001266                0.000000
# 5                  71                0.001344                0.000000
# 6                  72                0.001785                0.000000
# 7                  72                0.001022                0.000000
# 8                  72                0.390343                0.001807
#
#    u_statistic     auroc    pvalue  \
# 0        854.0  0.767296  0.000185
# 1        839.0  0.865841  0.000003
# 2        314.0  0.910145  0.001165
# 3        275.0  0.982143  0.000650
# 4        274.0  0.978571  0.000016
# 5        176.0  0.826291  0.020340
# 6        116.0  0.805556  0.051390
# 7         98.5  0.684028  0.133864
# 8         77.0  0.534722  0.440286
#
#                                            test_name  sensitivity_at_1pct  \
# 0  Mann-Whitney U (culture positive > culture neg...             0.867925
# 1  Mann-Whitney U (culture positive > culture neg...             1.000000
# 2  Mann-Whitney U (culture positive > culture neg...             0.800000
# 3  Mann-Whitney U (culture positive > culture neg...             1.000000
# 4  Mann-Whitney U (culture positive > culture neg...             0.250000
# 5  Mann-Whitney U (culture positive > culture neg...             0.333333
# 6  Mann-Whitney U (culture positive > culture neg...             0.000000
# 7  Mann-Whitney U (culture positive > culture neg...             0.000000
# 8  Mann-Whitney U (culture positive > culture neg...             0.500000
#
#    false_positive_rate_at_1pct    qvalue
# 0                     0.523810  0.000554
# 1                     0.701754  0.000024
# 2                     0.333333  0.002096
# 3                     0.457143  0.001462
# 4                     0.000000  0.000073
# 5                     0.140845  0.030510
# 6                     0.013889  0.066072
# 7                     0.000000  0.150597
# 8                     0.305556  0.440286
# ## Working Interpretation
# - Positive result: strongest descriptive agreement was P. aeruginosa (Mann-Whitney U=839.0, q=2.43e-05, AUROC=0.87).
# - Negative result: weakest supported target here was E. coli (Mann-Whitney q=0.44, AUROC=0.53).
# - Culture agreement is organism-group level, not strain-level or resistance-level agreement.
